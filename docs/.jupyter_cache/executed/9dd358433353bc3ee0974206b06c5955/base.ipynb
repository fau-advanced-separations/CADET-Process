# %%
import sys
sys.path.append('../../../../')

# %%
from CADETProcess.optimization import OptimizationProblem
optimization_problem = OptimizationProblem('normalization_demo')
# Out:
# [INFO 08-12 16:23:15] ax.storage.sqa_store.with_db_settings_base: Ax SQL storage initialized with SQLAlchemy 2.0.52

# %%
optimization_problem.add_variable('var_norm_lin', lb=-100, ub=100, normalization='linear')
# Out:
# RangedParameter(name='var_norm_lin', parameter_type=float, lb=-100, ub=100)

# %%
optimization_problem.add_variable('var_norm_log', lb=-100, ub=100, normalization='log')
# Out:
# RangedParameter(name='var_norm_log', parameter_type=float, lb=-100, ub=100)

# %%
optimization_problem.add_variable('var_norm_auto', lb=-100, ub=100, normalization='auto')
# Out:
# RangedParameter(name='var_norm_auto', parameter_type=float, lb=-100, ub=100)
