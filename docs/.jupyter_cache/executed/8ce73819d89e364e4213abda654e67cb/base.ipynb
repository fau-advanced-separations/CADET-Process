# %%
import sys
sys.path.append('../../../')

# %%
from CADETProcess.processModel import ComponentSystem

component_system = ComponentSystem(["simulation"])

# %%
from CADETProcess.processModel import LumpedRateModelWithoutPores

zone_template = LumpedRateModelWithoutPores(
    component_system,
    "zone_template",
    total_porosity=0.7,
    length=2.2e-3,
    axial_dispersion=7e-9,
)

# %%
from CADETProcess.modelBuilder import ZRMFlowSheetBuilder

builder = ZRMFlowSheetBuilder(
    configuration="axial",
    zone_template=zone_template,
    segments_area=[11.66e-04, 10.34e-04],
    void_in_volumes=[1.69e-06, 1.24e-06],
    void_out_volumes=[1.69e-06, 1.24e-06],
)

flow_sheet = builder.build_flow_sheet()

# %%
from CADETProcess.processModel import Inlet, Outlet

inlet = Inlet(component_system, "inlet")

flow_rate = 1e-6    # m^3/s
inlet.c = [1]       # mM
inlet.flow_rate = flow_rate

outlet = Outlet(component_system, "outlet")

# %%
import math
from CADETProcess.processModel import TubularReactor

delay_time = 3.0       # s

delay_tube = TubularReactor(component_system, "delay_tube")
delay_tube.length = 0.1
delay_tube.diameter = math.sqrt(
    (delay_time * flow_rate / delay_tube.length) * 4 / math.pi
)
delay_tube.axial_dispersion = 0  # no dispersion

# %%
flow_sheet.add_unit(inlet)
flow_sheet.add_unit(delay_tube)
flow_sheet.add_unit(outlet)

flow_sheet.add_connection(inlet, delay_tube)
flow_sheet.add_connection(delay_tube, builder.inlet_port)
flow_sheet.add_connection(builder.outlet_port, outlet)

# %%
from CADETProcess.processModel import Process
from CADETProcess.simulator import Cadet

simulator = Cadet()

process = Process(flow_sheet, "ZRM")
process.cycle_time = 50

results = simulator.simulate(process)

# %%
import numpy as np
from CADETProcess.reference import ReferenceIO

data = np.loadtxt('experimental_data/BSA_BTC_nonbinding.csv', delimiter=',')

time_experiment = data[:, 0]
c_experiment = data[:, 1]

from CADETProcess.reference import ReferenceIO
BTC = ReferenceIO(
    'BTC', time_experiment, c_experiment
)


from CADETProcess.comparison import Comparator

comparator = Comparator('experimental_data/BSA_BTC_nonbinding.csv')
comparator.add_reference(BTC)
comparator.add_difference_metric('RMSE', BTC, 'outlet.outlet')
comparator.evaluate(results)


_ = comparator.plot_comparison(results, x_axis_in_minutes=False, setup_figure_kwargs={"figsize": (6, 4)})
# Out:
# C:\Users\ezeiry\AppData\Local\Temp\ipykernel_21448\2829120622.py:18: DeprecationWarning: add_reference() is deprecated and will be removed in v1.0. Pass a pre-constructed metric instance to add_difference_metric() instead: metric = SSE(reference); comparator.add_difference_metric(metric, solution_path)
#   comparator.add_reference(BTC)
# C:\Users\ezeiry\AppData\Local\Temp\ipykernel_21448\2829120622.py:19: DeprecationWarning: Passing a metric class name as a string to add_difference_metric() is deprecated and will be removed in v1.0. Construct the metric directly and pass the instance instead: metric = SSE(reference); comparator.add_difference_metric(metric, solution_path)
#   comparator.add_difference_metric('RMSE', BTC, 'outlet.outlet')

# %%
from CADETProcess.modelBuilder import ZRMFlowSheetBuilder

builder = ZRMFlowSheetBuilder(
    configuration="axial",
    zone_template=zone_template,
    segments_area=[22e-04],
    void_in_volumes=[2.93e-06],
    void_out_volumes=[2.93e-06],
)

flow_sheet = builder.build_flow_sheet()

_ = results.solution.outlet.outlet.plot()
